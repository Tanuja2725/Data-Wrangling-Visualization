# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanuja2725/Visualization/blob/main/Aribnb_Market_Datavisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Airbnb Market

# %% [markdown]
# ![airbnb.webp](data:image/webp;base64,...)

# %% [markdown]
#                             #Airbnb hotels

# %% [markdown]
# ###What is Airbnb?
#
# (ans):Airbnb is a service that lets property owners rent out their spaces to travelers looking for a place to stay. Travelers can rent a space for multiple people to share, a shared space with private rooms, or the entire property for themselves.

# %% [markdown]
# #Table of contents:
#
# If you like my work, please upvote this notebook and can connect with me on GitHub and LinkdIn
#
#   1.Load Datas and Call libraries
#
#
#   2.Data Reading
#
#
#   3.Data Exploring
#
#
#   4.Data Clening
#
#
#   5.Data visualition

# %%
# Data source: Kaggle: '/kaggle/input/new-york-city-airbnb-open-data/AB_NYC_2019.csv'

# Spyder note: Use F9 in Spyder to execute a line and advance

# %% [markdown]
# #Load Datas and Call libraries

# %%
# Call libraries
# %reset -f
# 1.1 For data manipulations
import numpy as np
import pandas as pd
from numpy.random import default_rng

# 1.2 For plotting
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl     # For creating colormaps

# 1.2.1 Mosaic plots
# https://www.statsmodels.org/dev/graphics.html
# https://www.statsmodels.org/dev/generated/statsmodels.graphics.mosaicplot.mosaic.html#statsmodels.graphics.mosaicplot.mosaic
from statsmodels.graphics.mosaicplot import mosaic



# 1.3 For data processing
from sklearn.preprocessing import StandardScaler

# 1.4 OS related
import os

# 1.5 for working in ipython
#%matplotlib qt5
#%matplotlib inline


## 1.6 For generating random numbers:
rng = default_rng()

# %%
#1.6.1 From a cell display outputs from multiple commands:
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ##Mount gdrive

# %%
#1.7 Mount gdrive
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
#1.8 Set working folder and list files

path='/gdrive/MyDrive/colab_data_ files/Exercise/Airbnb_Open_Data.csv'

pathToFolder="/gdrive/MyDrive/colab_data_ files/Exercise/" 

os.chdir(pathToFolder)     #change working directory

os.listdir()               # List all files in the folder
# Out:
# ['archive.zip', 'buuk.csv', 'Airbnb_Open_Data.csv']

# %% [markdown]
# ##Read Dataset

# %%
#1.9 Read Data From CSV File

Airbnb=pd.read_csv('Airbnb_Open_Data.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (25) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ####Print the Shape of the dataset

# %%
#shape of data
Airbnb.shape
# Out:
# (102599, 26)

# %% [markdown]
# Print the Datatypes of the dataset

# %%
#data sets in data

Airbnb.dtypes
# Out:
# id                                  int64
# NAME                               object
# host id                             int64
# host_identity_verified             object
# host name                          object
# neighbourhood group                object
# neighbourhood                      object
# lat                               float64
# long                              float64
# country                            object
# country code                       object
# instant_bookable                   object
# cancellation_policy                object
# room type                          object
# Construction year                 float64
# price                              object
# service fee                        object
# minimum nights                    float64
# number of reviews                 float64
# last review                        object
# reviews per month                 float64
# review rate number                float64
# ...

# %% [markdown]
# ###obtaining information

# %%
#obtain information about the dataframe

Airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %% [markdown]
# #Data cleaning

# %%
#Removing the Duplicates if any

Airbnb.duplicated().sum()
Airbnb.drop_duplicates(inplace=True)
# Out:
# 541

# %%
#obtaining the description of the dataframe

Airbnb.describe()
# Out:
#                  id       host id            lat           long  \
# count  1.020580e+05  1.020580e+05  102050.000000  102050.000000
# mean   2.918438e+07  4.926738e+10      40.728097     -73.949652
# std    1.627173e+07  2.853742e+10       0.055852       0.049502
# min    1.001254e+06  1.236005e+08      40.499790     -74.249840
# 25%    1.509286e+07  2.459924e+10      40.688730     -73.982580
# 50%    2.918438e+07  4.912865e+10      40.722290     -73.954440
# 75%    4.327590e+07  7.400619e+10      40.762760     -73.932350
# max    5.736742e+07  9.876313e+10      40.916970     -73.705220
#
#        Construction year  minimum nights  number of reviews  \
# count      101844.000000   101658.000000      101875.000000
# mean         2012.488090        8.126640          27.517948
# std             5.765838       30.616698          49.571744
# min          2003.000000    -1223.000000           0.000000
# 25%          2007.000000        2.000000           1.000000
# ...

# %%
#display First Five rows of dataset

Airbnb.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
#check the columns

Airbnb.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
#check the column values

Airbnb.columns.values
# Out:
# array(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy',
#        'room type', 'Construction year', 'price', 'service fee',
#        'minimum nights', 'number of reviews', 'last review',
#        'reviews per month', 'review rate number',
#        'calculated host listings count', 'availability 365',
#        'house_rules', 'license'], dtype=object)

# %%
# Let us rename some columns; remove spaces

new_colu_names = {
                  'host id'                 : 'host_id',
                  'host name'               : 'host_name',
                 'neighbourhood group'      : 'neighbourhood_group' ,
                  'country code'            :  'country_code',
                  'room type'               :  'room_type',
                  'Construction year'       : 'Construction_year',
                  'service fee'             : 'service_fee',
                  'number of reviews'       :  'number_of_reviews' ,
                  'last review'             :  'lastreview',
                  'reviews per month'       : 'reviewspermonth',
                  'review rate number'      :  'reviewratenumber',
          'calculated host listings count'  :'calculatedhostlistingscount',
                  'availability 365'        :  'availability365'     ,
       
}

# %%
# rename column names


Airbnb.rename(
         columns = new_colu_names,
         inplace = True,
         )

# %%
#check renaming

Airbnb.head()
Airbnb.columns.values
# Out:
#         id                                              NAME      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service_fee minimum nights  \
# ...

# %% [markdown]
# #Data Exploring

# %% [markdown]
# ###Explore the unique values

# %%
#How many  unique NAMES do we have

Airbnb.NAME.nunique()
Airbnb.NAME.value_counts()
# Out:
# 61281
# Home away from home                                  33
# Hillside Hotel                                       30
# Water View King Bed Hotel Room                       30
# Brooklyn Apartment                                   27
# New york Multi-unit building                         27
#                                                      ..
# Modern & trendy serenity—great High Line location     1
# Quiet, light-filled, Soho apartment                   1
# Sunny and cozy room 10 minutes from Times Sq.61F3     1
# 1 bedroom apartment across the Central Park           1
# Parisian Style Apartment in Heart of Brooklyn         1
# Name: NAME, Length: 61281, dtype: int64

# %%
#how many unique prises do we have

Airbnb.price.nunique()
Airbnb.price.value_counts()
# Out:
# 1151
# $206       135
# $1,056     131
# $481       129
# $833       127
# $573       126
#           ...
# $923        57
# $369        57
# $786        54
# $89         53
# $187        52
# Name: price, Length: 1151, dtype: int64

# %%
#examining the unique values of n_group as this column will appear very handy for later analysis

Airbnb.neighbourhood_group.unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'brookln', 'manhatan', 'Queens', nan,
#        'Staten Island', 'Bronx'], dtype=object)

# %%
#examining the unique values of room_type as this column will appear very handy for later analysis

Airbnb.room_type.unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room', 'Hotel room'],
#       dtype=object)

# %%
#let's see what hosts (IDs) have the most listings on Airbnb platform and taking advantage of this service

top_host=Airbnb.host_id.value_counts().head(10)
top_host
# Out:
# 29531702698    2
# 50581630001    1
# 68762673377    1
# 73658732887    1
# 19885857361    1
# 29903509309    1
# 50619881526    1
# 38203590171    1
# 6142567966     1
# 51634917141    1
# Name: host_id, dtype: int64

# %%
#coming back to our dataset we can confirm our fidnings with already existing column called 'calculated_host_listings_count'

top_host_check=Airbnb.calculatedhostlistingscount.max()
top_host_check
# Out:
# 332.0

# %%
#calculating the top host list

top_host_Airbnb=pd.DataFrame(top_host)
top_host_Airbnb.reset_index(inplace=True)
top_host_Airbnb.rename(columns={'index':'Host_ID', 'host_id':'P_Count'}, inplace=True)
top_host_Airbnb
# Out:
#        Host_ID  P_Count
# 0  29531702698        2
# 1  50581630001        1
# 2  68762673377        1
# 3  73658732887        1
# 4  19885857361        1
# 5  29903509309        1
# 6  50619881526        1
# 7  38203590171        1
# 8   6142567966        1
# 9  51634917141        1

# %%
#distribution of number of reviews

Airbnb.number_of_reviews.value_counts()
# Out:
# 0.0      15673
# 1.0      10348
# 2.0       7129
# 3.0       5341
# 4.0       4125
#          ...
# 567.0        1
# 592.0        1
# 797.0        1
# 966.0        1
# 300.0        1
# Name: number_of_reviews, Length: 476, dtype: int64

# %% [markdown]
# Understadning, Wrangling and Cleaning Data

# %%
#after looking at the head of the dataset we already were able to notice some NaN values, therefore need to examine missing values further before continuing with analysis

#looking to find out first what columns have null values
#using 'sum' function will show us how many nulls are found in each column in dataset

Airbnb.isnull().sum()
# Out:
# id                                  0
# NAME                              250
# host_id                             0
# host_identity_verified            289
# host_name                         404
# neighbourhood_group                29
# neighbourhood                      16
# lat                                 8
# long                                8
# country                           532
# country_code                      131
# instant_bookable                  105
# cancellation_policy                76
# room_type                           0
# Construction_year                 214
# price                             247
# service_fee                       273
# minimum nights                    400
# number_of_reviews                 183
# lastreview                      15832
# reviewspermonth                 15818
# reviewratenumber                  319
# calculatedhostlistingscount       319
# availability365                   448
# house_rules                     51842
# ...

# %%
#dropping columns that are not significant or could be unethical to use for our future data exploration and predictions

Airbnb.drop(['reviewratenumber','country_code'], axis=1, inplace=True)

# %%
#Examing changes

Airbnb.head(5)
# Out:
#         id                                              NAME      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ...  price service_fee minimum nights  \
# ...

# %%
Airbnb.columns
# Out:
# Index(['id', 'NAME', 'host_id', 'host_identity_verified', 'host_name',
#        'neighbourhood_group', 'neighbourhood', 'lat', 'long', 'country',
#        'instant_bookable', 'cancellation_policy', 'room_type',
#        'Construction_year', 'price', 'service_fee', 'minimum nights',
#        'number_of_reviews', 'lastreview', 'reviewspermonth',
#        'calculatedhostlistingscount', 'availability365', 'house_rules',
#        'license'],
#       dtype='object')

# %%
#categorize the neighbourhood group into categories


Airbnb["neighbourhood"].value_counts()


Airbnb.neighbourhoodgroup = Airbnb.neighbourhood_group.astype('category')
# Out:
# Bedford-Stuyvesant        7898
# Williamsburg              7732
# Harlem                    5441
# Bushwick                  4956
# Hell's Kitchen            3949
#                           ...
# Willowbrook                  3
# Gerritsen Beach              3
# Fort Wadsworth               2
# Glen Oaks                    2
# Chelsea, Staten Island       1
# Name: neighbourhood, Length: 224, dtype: int64
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   import sys

# %%
#print the categories in neighbourhood group


Airbnb.neighbourhoodgroup.cat.categories
# Out:
# Index(['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'brookln',
#        'manhatan'],
#       dtype='object')

# %%
#crosstab the columns neighbourhood group and room type

pd.crosstab(Airbnb.neighbourhoodgroup, Airbnb.room_type)
# Out:
# room_type            Entire home/apt  Hotel room  Private room  Shared room
# neighbourhood_group
# Bronx                           1020           0          1559          115
# Brooklyn                       20475           7         20324          824
# Manhattan                      26331         100         16231          895
# Queens                          5118           8          7712          359
# Staten Island                    474           0           460           15
# brookln                            0           0             1            0
# manhatan                           0           0             1            0

# %%
# how many unique values in nighbourhood.

total_unique_values =Airbnb["neighbourhood"].unique().shape[0]
print(f"Total unique values:           {total_unique_values}")
print(f"% of unique values to overall: {round(total_unique_values/Airbnb['neighbourhood'].shape[0] * 100, 2)}%")
# Out:
# Total unique values:           225
# % of unique values to overall: 0.22%

# %%
# Revenue column
# In order to see the income that each Airbnb makes, we have to create a 'revenue' column.
# This revenue column will be the amount of days booked per year, multiplied by the 'price' column.
# First we have to get the amount of days booked. We will take 365 (days per year), minus the days available.

# Let's look at the values in our Availibility column

Airbnb['availability365'].describe()
# Out:
# count    101610.000000
# mean        141.043992
# std         135.429156
# min         -10.000000
# 25%           3.000000
# 50%          96.000000
# 75%         268.000000
# max        3677.000000
# Name: availability365, dtype: float64

# %%
Airbnb['availability365'].loc[Airbnb['availability365'] < 0] = 0
Airbnb['availability365'].loc[Airbnb['availability365'] > 365] = 365
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
Airbnb['availability365'] = (365 - Airbnb['availability365'])
Airbnb.rename(columns={'availability365': 'Days booked'},inplace=True)

# %% [markdown]
# ##removing the Dallar sign

# %%
# remove the $ sign and unwanted characters from the records

def remove_dollar_sign(value):
    if pd.isna(value):
        return np.NaN
    else:
        return float(value.replace("$", "").replace(",", "").replace(" ", ""))
    
Airbnb["price"] = Airbnb["price"].apply(lambda x: remove_dollar_sign(x))

# %%
# remove the $ sign and unwanted characters from the records

Airbnb["service_fee"] = Airbnb["service_fee"].apply(lambda x: remove_dollar_sign(x))

# %% [markdown]
# ###Correlations

# %%
# Correlations

# It would be usefull to look at how the different columns correlate to each other.
# This can help us gain futher insight and direct our analysis to interesting aspects that we might observe.

# %%
Correlations = Airbnb.corr()

# %%
# We can even create a heatmap based on these correlations:

Correlations

sns.heatmap(Correlations)
# Out:
#                                    id   host_id       lat      long  \
# id                           1.000000 -0.001189 -0.008600  0.042483
# host_id                     -0.001189  1.000000  0.000389 -0.008805
# lat                         -0.008600  0.000389  1.000000  0.074427
# long                         0.042483 -0.008805  0.074427  1.000000
# Construction_year            0.000994  0.004726  0.005489  0.001480
# price                        0.006811  0.003624 -0.005575  0.003356
# service_fee                  0.007168  0.003418 -0.005563  0.003201
# minimum nights               0.005305 -0.002359  0.014918 -0.039551
# number_of_reviews           -0.042115 -0.004800 -0.025154  0.069202
# reviewspermonth              0.038153 -0.001980 -0.019686  0.119059
# calculatedhostlistingscount  0.024062  0.001733  0.032314 -0.104230
# Days booked                  0.135074  0.002274  0.005905 -0.060172
#
#                              Construction_year     price  service_fee  \
# ...

# %% [markdown]
#     Here we can already see that there is some columns that correlate with each other.

# %% [markdown]
# ###apply the ANOVA test to our list, and end up with our printed 'P-value'

# %%
# import the necessary library.

from scipy.stats import f_oneway

# %%
# we create a list, that contains all of our selected data, from the 'room type' and 'price' columns.


category_list = Airbnb.groupby('room_type')['price'].apply(list)
Annova_result = f_oneway(*category_list)
print('P-value for Annova is : ',Annova_result[0])
# Out:
# P-value for Annova is :  nan

# %%
category_list
# Out:
# room_type
# Entire home/apt    [142.0, 368.0, 204.0, 577.0, 319.0, 606.0, 578...
# Hotel room         [594.0, 247.0, 624.0, 286.0, 938.0, 663.0, 490...
# Private room       [966.0, 620.0, 71.0, 1060.0, 1018.0, 291.0, 71...
# Shared room        [1010.0, 586.0, 599.0, 67.0, 910.0, 644.0, 712...
# Name: price, dtype: object

# %%
#lets get our unique values for cancellation policy


Airbnb['cancellation_policy'].value_counts()
# Out:
# moderate    34162
# strict      33929
# flexible    33891
# Name: cancellation_policy, dtype: int64

# %%
# Now we can apply the ANOVA test once again

cat_list = Airbnb.groupby('cancellation_policy')['price'].apply(list)
Annova_result = f_oneway(*cat_list)
print('P-value for Annova is : ',Annova_result[0])
# Out:
# P-value for Annova is :  nan

# %%
cat_list
# Out:
# cancellation_policy
# flexible    [620.0, 577.0, 319.0, 606.0, 149.0, 578.0, 656...
# moderate    [142.0, 368.0, 204.0, 71.0, 1060.0, 580.0, 778...
# strict      [966.0, 1018.0, 291.0, 714.0, 816.0, 1175.0, 2...
# Name: price, dtype: object

# %% [markdown]
# #Visualization of data

# %%
# create a function to plot bar chart

def plot_bar_chart(column_name: str, hue: str=None, top_values: int = None, palette: str = "flare", show_grid : bool = True, 
                   figsize: tuple = (16, 9), bar_font_size: int=14, bar_angle: int=45, angle: int=45):
    fig = plt.figure(facecolor = (247/255, 247/255, 247/255), figsize = figsize)
    ax = plt.subplot(1, 1, 1)
    
    ax.set_facecolor((247/255, 247/255, 247/255))
    counts = None
    
    if top_values is not None:
        counts = Airbnb[column_name].value_counts().iloc[:top_values]
    else:
        counts = Airbnb[column_name].value_counts()
        
    bar_ax = sns.barplot(x = counts.keys(), y = counts, palette = palette, ax = ax, hue = Airbnb[hue] if hue is not None else None) 
    
                               
    plt.xticks(rotation = angle, fontsize = 14)
    plt.xlabel(f"{column_name}", fontweight="bold", fontsize = 18)
    plt.ylabel("count", fontweight="bold", fontsize = 18)
    plt.title(f"Top {top_values} {column_name}" if top_values is not None else f"{column_name}", fontsize = 27)
    if show_grid: plt.grid()
    plt.show()

# %%
# create a function to plot pie/donut chart
def plot_pie_chart(column_name: str, startangle: int=45, loc: str="center", explodes: float=0.09, colors: list = None):
    values = Airbnb[column_name].value_counts()
    keys = values.keys()
    total_records = Airbnb[column_name].count()

    labels = ["{0} - {1:1.2f} %".format(i, j/total_records * 100) for i, j in zip(keys, values)]
    explodes = [explodes/len(keys) for i in range(len(keys))]

    plt.subplots(figsize = (16, 9))
    # draw the pie chart
    patches, texts = plt.pie(values, startangle = startangle, explode = explodes, colors = colors)

    # draw circle
    center_circle = plt.Circle(xy = (0, 0), radius = 0.70, fc = "white")
    fig = plt.gcf()
    fig.gca().add_artist(center_circle)

    plt.title(column_name, fontsize = 25, fontweight = "bold")
    plt.legend(patches, labels, loc=loc, fontsize = 14)
    plt.show()

# %%
# create a function to plot line chart
def plot_line_chart(column_name, xlabel, ylabel, title):
    value = Airbnb[column_name].value_counts().sort_index()
    keys = np.array(value.keys(), dtype = np.int16)

    fig = plt.figure(facecolor = (247/255, 247/255, 247/255), figsize = (16, 7))
    ax  = plt.subplot(1, 1, 1)
    ax.set_facecolor((247/255, 247/255, 247/255))
    ax.plot(value, 'o--', c="black", markerfacecolor='none', markersize=12, markeredgecolor="red", markeredgewidth = 3, linewidth=2)
    plt.xlabel(xlabel, fontsize = 20, fontweight = "bold")
    plt.ylabel(ylabel, fontsize = 20, fontweight = "bold")
    plt.xticks(ticks = keys, fontsize = 12, rotation = 15)
    plt.title(title, fontsize = 24, fontweight = "bold")
    plt.show()

# %%
#new column

plot_bar_chart(column_name = "NAME", top_values = 30, palette = "flare", show_grid = True, angle = 85)

# %% [markdown]
#                       here we are seen every column name and count

# %%
#plot the barchat for host identity verified:

plot_bar_chart("host_identity_verified", palette = "mako", figsize = (7,6), show_grid = False, bar_font_size = 10, bar_angle = 0, angle = 0)

# %% [markdown]
#               here is the observation of verification of host identity for every count

# %%
#plot the piechart for  host_identity_verified

plot_pie_chart("host_identity_verified", explodes = 0.03, colors = ["#ff9999", "#66b3ff"])

# %% [markdown]
#             here is the observation of verified host with % of 49.94 and uncomformed host % is 50.06%

# %%
#plot the barchat for  names of host   

plot_bar_chart("host_name", top_values = 30, palette = "magma", show_grid = False, angle = 60)

# %% [markdown]
#             here is the observation of different host names with number of times count

# %%
#plot the barchart for  each neighbourhood group 

plot_bar_chart("neighbourhood_group", palette = "cubehelix", show_grid = False, bar_angle = 0, figsize = (20, 7), angle = 0)

# %% [markdown]
#                       here is the observation of neighbourhood group form with 5-manhattan,brooklyn,queens,bronx,and staten island and manhattan having most counts

# %%
#plot the pie chart for neighbourhood group

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99', "#e79cee", "#9ce7ee", "#d9ee9c"]
plot_pie_chart("neighbourhood_group", explodes = 0.09, colors = colors)

# %% [markdown]
#         Here each colour indicates the % of each ,and most of guests are in Manhattan

# %%
#plot the barchart for neighbourhood 

plot_bar_chart("neighbourhood", top_values = 30, palette = "dark:salmon_r", show_grid = False, angle = 75)

# %% [markdown]
#                 here is the observation of each city which is nighbourhood eachother

# %%
#plot the barchart for  instant booking

plot_bar_chart(column_name = "instant_bookable", palette = "YlOrBr", show_grid = False, bar_angle = 0, angle = 0, figsize = (7, 7))

# %% [markdown]
#       here we are observing instant booking status is 50.50

# %%
#plot the pie chart for instant booking

plot_pie_chart(column_name = "instant_bookable", startangle = 90, explodes = 0.025, colors = ['#ff9999','#66b3ff'])

# %% [markdown]
#     here is two colors indication and observation is even same

# %%
#plot the barchart for  cancellation policy

plot_bar_chart(column_name = "cancellation_policy", figsize = (10, 7), bar_angle = 0, angle = 0, show_grid = False)

# %% [markdown]
#         here is the observation of 3 types of cancellation policies and those have similar chances

# %%
#plot the pie chart for cancellation polocy

plot_pie_chart("cancellation_policy", startangle = 90, colors = ['#ff9999','#66b3ff','#99ff99'])

# %% [markdown]
#       here is the observation of 3 types of cancellation policies and those have similar chances

# %%
#plot the barchart for type of rooms

plot_bar_chart(column_name="room_type", palette="YlOrBr", show_grid=False, bar_angle=0, angle=0, figsize = (12, 7))

# %% [markdown]
#       here 3 types of roos those are Entire home,private room,Shared room.and sharing room are very  less

# %%
#plot the pie chart for types of rooms

plot_pie_chart(column_name="room_type", explodes=0.2, colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99'])

# %% [markdown]
#            here 3 types of roos those are Entire home,private room,Shared room.and sharing room are very  less

# %%
#plot the line chart  for construction year and year,count

plot_line_chart("Construction_year", "Year", "Count", "Construction_Year")

# %% [markdown]
#             here the line indicates 3 values construction year ,year and count.

# %%
plt.figure(figsize=(15,5))
ax = sns.countplot(Airbnb["room_type"],palette='winter')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
#     here is the observation of rooms

# %%
#plot distribution plot for price

sns.histplot(data=Airbnb,x='price',bins=5);

# %% [markdown]
#         here is price is for each distribution

# %%
#plot the  scatter plot for host id and price

sns.jointplot(data=Airbnb,x='host_id',y='price',kind='kde')

# %%
#plot the Scatterplot for Minimum nights and Service fee

plt.scatter(x=Airbnb['minimum nights'], y=Airbnb['service_fee'])

plt.title('Scatterplot for Minimum nights and Service fee')
plt.xlabel('Minimum nights')
plt.ylabel('Service_fee')
# Out:
# Text(0.5, 1.0, 'Scatterplot for Minimum nights and Service fee')
# Text(0.5, 0, 'Minimum nights')
# Text(0, 0.5, 'Service_fee')

# %% [markdown]
#         here is the observation of minimum nights having high service fee

# %%
# plot boxplot for room type and price

sns.boxplot(y = 'price',       # Discrete
            x = 'room_type',                 # Continuous
            data = Airbnb
            )

# %% [markdown]
#       here we are observing different prices and rooms

# %%
#Neighbourhood and eight neigbourhoods have over one thousand listings.


feq=Airbnb['neighbourhood'].value_counts().sort_values(ascending=True)
feq.plot.barh(figsize=(10, 8), color='b', width=1)
plt.title("Number of listings by neighbourhood", fontsize=20)
plt.xlabel('Number of listings', fontsize=12)
plt.show()
# Out:
# Text(0.5, 1.0, 'Number of listings by neighbourhood')
# Text(0.5, 0, 'Number of listings')

# %%
#let's what we can do with our given longtitude and latitude columns

#let's see how scatterplot will come out 

sub=Airbnb[Airbnb.price < 500]
view=sub.plot(kind='scatter', x='long', y='lat', label='availability_365', c='price',
                  cmap=plt.get_cmap('jet'), colorbar=True, alpha=0.4, figsize=(10,8))
view.legend()

# %% [markdown]
#       Good, scatterplot worked just fine to output our latitude and longitude points. However, it would be nice to have a map bellow for fully immersive heatmap in ourcase - let's see what we can do!

# %%
import urllib
#initializing the figure size
plt.figure(figsize=(10,8))
#loading the png NYC image found on Google and saving to my local folder along with the project
i=urllib.request.urlopen('https://upload.wikimedia.org/wikipedia/commons/e/ec/Neighbourhoods_New_York_City_Map.PNG')
nyc_img=plt.imread(i)
#scaling the image based on the latitude and longitude max and mins for proper output
plt.imshow(nyc_img,zorder=0,extent=[-74.258, -73.7, 40.49,40.92])
ax=plt.gca()
#using scatterplot again
sub.plot(kind='scatter', x='long', y='lat', label='availability_365', c='price', ax=ax, 
           cmap=plt.get_cmap('jet'), colorbar=True, alpha=0.4, zorder=5)

plt.legend()
plt.show()

# %% [markdown]
# After scaling our image the best we can, we observe that we end up with a very immersive heatmap. Using latitude and longitude points were able to visualize all NYC listings. Also, we added a color-coded range for each point on the map based on the price of the listing. However, it is important to note that we had to drop some extremely high values as they are treated as outliers for our analysis
